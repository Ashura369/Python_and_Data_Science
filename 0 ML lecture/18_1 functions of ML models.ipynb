# %% [markdown]
# ## **Making a function for all ML models to use**

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score

import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
def modelTrain(reg, X, y, size, random, ohe=None, oe=None, le=None):       # In Python, all parameters with default values (like ohe=None) must come after all parameters without default values.
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=size, random_state=random)

    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)

    print(f"ACCURACY : {accuracy_score(y_test, y_pred)*100} %")


pickle.dump(modelTrain, open('models/modelTrain.pkl', 'wb'))
