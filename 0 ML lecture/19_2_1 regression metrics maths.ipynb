# %% [markdown]
# # **Maths**

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('placement (1).csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
sns.scatterplot(x=df['cgpa'], y=df['package'])
plt.legend()
plt.xlabel('CGPA')
plt.ylabel('PACKAGE')
plt.show()

# %%
X = df.iloc[:, :1]
y = df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)
lr = LinearRegression()

lr.fit(X_train, y_train)


y_pred = lr.predict(X_test)      # since the data is in 1D, we have to reshape it to (1, 1)

# %%
print(f"MAE \t: {mean_absolute_error(y_test, y_pred)}")
print(f"MSE \t: {mean_squared_error(y_test, y_pred)}")
print(f"RMSE \t: {np.sqrt(mean_squared_error(y_test, y_pred))}")    # since there is no specific function for RMSE you have to use "np.sqrt"
print(f"R2 \t: {r2_score(y_test, y_pred)}")
# Out:
# MAE 	: 0.2884710931878175
# MSE 	: 0.12129235313495527
# RMSE 	: 0.34827051717731616
# R2 	: 0.780730147510384

# %%
print(X_test.shape)

r2 = r2_score(y_test, y_pred)
1 - ((1 - r2) * (40 - 1) / (40 - 1 - 1))        # this is how you have to find adjusted r2
# 40 = rows
# (40 - 1 - 1) / (n - k - 1) = 1 in the middle is the total number of features in the data
# Out:
# (40, 1)
# 0.7749598882343415
