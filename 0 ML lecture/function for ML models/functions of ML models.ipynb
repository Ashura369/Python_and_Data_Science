# %% [markdown]
# ## **Making a function for all ML models to use**

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
# df = pd.read_csv('D:/THE CODE/python/0 ML lecture/train.csv')

# X = df.drop(columns='Survived', axis=1)
# y = df[['Survived']]

# lr = LinearRegression()

# modelTrain(lr, X, y, 0.2, 42)

# %%
def modelTrain (reg, X, y, ohe=None, oe=None, le=None, size, random):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=size, random_state=random)
