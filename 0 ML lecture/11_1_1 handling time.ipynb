# %% [markdown]
# # Handling time

# %%
import pandas as pd
import numpy as np

# %%
time = pd.read_csv('messages.csv')
date = pd.read_csv('orders.csv')

date = date.drop(columns=['product_id', 'city_id', 'orders'])
time = time.drop(columns=['msg'])
time.head()
# Out:
#                   date
# 0  2013-12-15 00:50:00
# 1  2014-04-29 23:40:00
# 2  2012-12-30 00:21:00
# 3  2014-11-28 00:31:00
# 4  2013-10-26 23:11:00

# %% [markdown]
# ### **Working with time**

# %%
time['date'] = pd.to_datetime(time['date'])
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %%
# extracting hour, minute, and seconds
time['hour'] = time['date'].dt.hour
time['minute'] = time['date'].dt.minute
time['second'] = time['date'].dt.second

time.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hour'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4490, in DataFrame._set_item_mgr(self, key, value, refs)
#    4489 try:
# -> 4490     loc = self._info_axis.get_loc(key)
#    4491 except KeyError:
#    4492     # This item wasn't present, just insert at end
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#
# KeyError: 'hour'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 # extracting hour, minute, and seconds
# ----> 2 time['hour'] = time['date'].dt.hour
#       3 time['minute'] = time['date'].dt.minute
#       4 time['second'] = time['date'].dt.second
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4543, in DataFrame._set_item(self, key, value)
#    4540             value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4541             refs = None
# -> 4543 self._set_item_mgr(key, value, refs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4493, in DataFrame._set_item_mgr(self, key, value, refs)
#    4490     loc = self._info_axis.get_loc(key)
#    4491 except KeyError:
#    4492     # This item wasn't present, just insert at end
# -> 4493     self._mgr.insert(len(self._info_axis), key, value, refs)
#    4494 else:
#    4495     self._iset_item_mgr(loc, value, refs=refs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:1385, in BlockManager.insert(self, loc, item, value, refs)
#    1383 else:
#    1384     self._insert_update_mgr_locs(loc)
# -> 1385     self._insert_update_blklocs_and_blknos(loc)
#    1387 self.axes[0] = new_axis
#    1388 self.blocks += (block,)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:1421, in BlockManager._insert_update_blklocs_and_blknos(self, loc)
#    1418 # Accessing public blklocs ensures the public versions are initialized
#    1419 if loc == self.blklocs.shape[0]:
#    1420     # np.append is a lot faster, let's use it if we can.
# -> 1421     self._blklocs = np.append(self._blklocs, 0)
#    1422     self._blknos = np.append(self._blknos, len(self.blocks))
#    1423 elif loc == 0:
#    1424     # np.append is a lot faster, let's use it if we can.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\lib\_function_base_impl.py:5690, in append(arr, values, axis)
#    5688     if arr.ndim != 1:
#    5689         arr = arr.ravel()
# -> 5690     values = ravel(values)
#    5691     axis = arr.ndim-1
#    5692 return concatenate((arr, values), axis=axis)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:2017, in ravel(a, order)
#    1913 @array_function_dispatch(_ravel_dispatcher)
#    1914 def ravel(a, order='C'):
#    1915     """Return a contiguous flattened array.
#    1916
#    1917     A 1-D array, containing the elements of the input, is returned.  A copy is
#    (...)   2015
#    2016     """
# -> 2017     if isinstance(a, np.matrix):
#    2018         return asarray(a).ravel(order=order)
#    2019     else:
#
# AttributeError: module 'numpy' has no attribute 'matrix'

# %%
# as both date and time are mentioned together, hence extracting time separately
time['time'] = time['date'].dt.time
time.head(3)
# Out:
#                  date  hour  minute  second      time
# 0 2013-12-15 00:50:00     0      50       0  00:50:00
# 1 2014-04-29 23:40:00    23      40       0  23:40:00
# 2 2012-12-30 00:21:00     0      21       0  00:21:00

# %%
# extracting time difference
import datetime         
today = datetime.datetime.today()
today - time['date']
# Out:
# 0     4366 days 05:52:13.335361
# 1     4230 days 07:02:13.335361
# 2     4716 days 06:21:13.335361
# 3     4018 days 06:11:13.335361
# 4     4415 days 07:31:13.335361
#                  ...
# 995   5005 days 05:52:13.335361
# 996   4326 days 07:28:13.335361
# 997   4791 days 07:05:13.335361
# 998   4907 days 07:08:13.335361
# 999   4179 days 07:17:13.335361
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# extracting in seconds
(today - time['date']) / np.timedelta64(1, 's')
# Out:
# 0      3.772435e+08
# 1      3.654973e+08
# 2      4.074853e+08
# 3      3.471775e+08
# 4      3.814831e+08
#            ...
# 995    4.324531e+08
# 996    3.737933e+08
# 997    4.139679e+08
# 998    4.239905e+08
# 999    3.610918e+08
# Name: date, Length: 1000, dtype: float64

# %%
# extracting minutes
(today - time['date']) / np.timedelta64(1, 'm')
# Out:
# 0      6.287392e+06
# 1      6.091622e+06
# 2      6.791421e+06
# 3      5.786291e+06
# 4      6.358051e+06
#            ...
# 995    7.207552e+06
# 996    6.229888e+06
# 997    6.899465e+06
# 998    7.066508e+06
# 999    6.018197e+06
# Name: date, Length: 1000, dtype: float64

# %%
# extracting hours
(today - time['date']) / np.timedelta64(1, 'h')
# Out:
# 0      104789.870371
# 1      101527.037038
# 2      113190.353704
# 3       96438.187038
# 4      105967.520371
#            ...
# 995    120125.870371
# 996    103831.470371
# 997    114991.087038
# 998    117775.137038
# 999    100303.287038
# Name: date, Length: 1000, dtype: float64
