# %% [markdown]
# **<h1>Learning Plotly</h1>**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# import dataset
df = pd.read_csv("Final Visualization Dataset.csv")

# %%
with pd.option_context('display.max_columns',None):
    display(df.sample(5))
# Out:
#      Age  Attrition Business Travel  Compensation Rate  \
# 676   35          0   Travel_Rarely               1137
# 954   42          0      Non-Travel                495
# 363   33          1   Travel_Rarely                350
# 399   31          0   Travel_Rarely                329
# 505   26          0   Travel_Rarely                991
#
#                  Department  Distance From Home  Education Education Field  \
# 676  Research & Development                  21          1   Life Sciences
# 954  Research & Development                   2          1   Life Sciences
# 363                   Sales                   5          3       Marketing
# 399  Research & Development                   1          2   Life Sciences
# 505  Research & Development                   6          3   Life Sciences
#
#      Environment Satisfaction  Gender  Hourly Rate  Job Involvement  \
# 676                         4  Female           51                3
# 954                         3    Male           37                3
# 363                         4  Female           34                3
# 399                         4    Male           98                2
# 505                         3  Female           71                3
#
#      Job Level                   Job Role  Job Satisfaction Marital Status  \
# 676          2  Healthcare Representative                 4        Married
# 954          4                    Manager                 3        Married
# 363          1       Sales Representative                 3         Single
# 399          1      Laboratory Technician                 1        Married
# 505          1      Laboratory Technician                 4        Married
#
#      Monthly Income  Monthly Rate  Num Companies Worked Over Time  \
# 676            4014         19170                     1       Yes
# 954           17861         26582                     0       Yes
# 363            2851          9150                     1       Yes
# 399            2218         16193                     1        No
# 505            2659         17759                     1       Yes
#
#      Percent Salary Hike  Performance Rating  Relationship Satisfaction  \
# 676                   25                   4                          4
# 954                   13                   3                          4
# 363                   13                   3                          2
# 399                   12                   3                          3
# 505                   13                   3                          3
#
#      Stock Option Level  Total Working Years  Training Times Last Year  \
# 676                   1                   10                         2
# 954                   0                   21                         3
# 363                   0                    1                         2
# 399                   1                    4                         3
# 505                   1                    3                         2
#
#      Work Life Balance  Years At Company  Years In Current Role  \
# 676                  1                10                      6
# 954                  2                20                      8
# 363                  3                 1                      0
# 399                  3                 4                      2
# 505                  3                 3                      2
#
#      Years Since Last Promotion  Years With Curr Manager Education Labels  \
# 676                           0                        7    Below College
# 954                           2                       10    Below College
# 363                           0                        0         Bachelor
# 399                           3                        2          College
# 505                           0                        2         Bachelor
#
#     Environment Satisfaction Labels Job Involvement Labels  \
# 676                       Very High        Highly Involved
# 954                            High        Highly Involved
# 363                       Very High        Highly Involved
# 399                       Very High    Moderately Involved
# 505                            High        Highly Involved
#
#         Job Level Label Relationship Satisfaction Labels  \
# 676           Mid-Level                   Very Satisfied
# 954   Staff / Principal                   Very Satisfied
# 363  Associate / Junior                     Dissatisfied
# 399  Associate / Junior                        Satisfied
# 505  Associate / Junior                        Satisfied
#
#      Avg Tenure Per Company           Candidate Stability  Training Intensity  \
# 676                    10.0       High Stability (5+ yrs)                0.20
# 954                    42.0       High Stability (5+ yrs)                0.15
# 363                     1.0       Low Stability (< 2 yrs)                2.00
# 399                     4.0  Moderate Stability (2-5 yrs)                0.75
# 505                     3.0  Moderate Stability (2-5 yrs)                0.67
#
#     Work Life Balance Labels  Role Stagnation Index  Promotion Gap Ratio  \
# 676                     Poor                   0.60                 0.00
# 954                     Fair                   0.40                 0.10
# 363                     Good                   0.00                 0.00
# 399                     Good                   0.50                 0.75
# 505                     Good                   0.67                 0.00
#
#      Manager Stability Indicator Manager Stability Indicator Labels  \
# 676                            3                             Stable
# 954                            4                      Highly Stable
# 363                            1                   New Relationship
# 399                            2                         Developing
# 505                            2                         Developing
#
#          Promotion Risk Cluster
# 676  Fast-Track High Performers
# 954   Tenured & Stalled Seniors
# 363      Early-Career Explorers
# 399      Early-Career Explorers
# 505      Early-Career Explorers

# %% [markdown]
# ---

# %% [markdown]
# ### **Histogram**

# %%
fig = px.histogram(df, x='Education Field', color='Education Field', text_auto=True)        # text position shows the count labels
fig.update_traces(textposition='outside')                                                   # shows the count labels outside of histplots
fig.show()

# %%
fig = px.histogram(df, x='Job Role', color='Job Role', text_auto=True, height=600)
fig.update_traces(textposition='outside')
fig.show()
