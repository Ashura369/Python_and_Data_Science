# %% [markdown]
# **<h1>Learning Plotly</h1>**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# import dataset
df = pd.read_csv("Final Visualization Dataset.csv")

# %%
with pd.option_context('display.max_columns',None):
    display(df.sample(5))
# Out:
#       Age  Attrition    Business Travel  Compensation Rate  \
# 322    32          0      Travel_Rarely               1018
# 439    31          1  Travel_Frequently                534
# 1266   41          0      Travel_Rarely                548
# 671    34          0      Travel_Rarely                546
# 1249   29          1      Travel_Rarely                428
#
#                   Department  Distance From Home  Education Education Field  \
# 322   Research & Development                   2          4         Medical
# 439   Research & Development                  20          3   Life Sciences
# 1266  Research & Development                   9          4   Life Sciences
# 671   Research & Development                  10          3   Life Sciences
# 1249                   Sales                   9          3       Marketing
#
#       Environment Satisfaction  Gender  Hourly Rate  Job Involvement  \
# 322                          1  Female           74                4
# 439                          1    Male           66                3
# 1266                         3    Male           94                3
# 671                          2    Male           83                3
# 1249                         2  Female           52                1
#
#       Job Level                   Job Role  Job Satisfaction Marital Status  \
# 322           2         Research Scientist                 4         Single
# 439           3  Healthcare Representative                 3        Married
# 1266          1      Laboratory Technician                 1       Divorced
# 671           1      Laboratory Technician                 2       Divorced
# 1249          1       Sales Representative                 2         Single
#
#       Monthly Income  Monthly Rate  Num Companies Worked Over Time  \
# 322             5055         10557                     7        No
# 439             9824         22908                     3        No
# 1266            2289         20520                     1        No
# 671             2008          6896                     1        No
# 1249            2760         14630                     1        No
#
#       Percent Salary Hike  Performance Rating  Relationship Satisfaction  \
# 322                    16                   3                          3
# 439                    12                   3                          1
# 1266                   20                   4                          2
# 671                    14                   3                          2
# 1249                   13                   3                          3
#
#       Stock Option Level  Total Working Years  Training Times Last Year  \
# 322                    0                   10                         0
# 439                    0                   12                         2
# 1266                   2                    5                         2
# 671                    2                    1                         3
# 1249                   0                    2                         3
#
#       Work Life Balance  Years At Company  Years In Current Role  \
# 322                   2                 7                      7
# 439                   3                 1                      0
# 1266                  3                 5                      3
# 671                   3                 1                      0
# 1249                  3                 2                      2
#
#       Years Since Last Promotion  Years With Curr Manager Education Labels  \
# 322                            0                        7           Master
# 439                            0                        0         Bachelor
# 1266                           0                        4           Master
# 671                            1                        0         Bachelor
# 1249                           2                        2         Bachelor
#
#      Environment Satisfaction Labels Job Involvement Labels  \
# 322                              Low        Fully Dedicated
# 439                              Low        Highly Involved
# 1266                            High        Highly Involved
# 671                           Medium        Highly Involved
# 1249                          Medium     Minimally Involved
#
#          Job Level Label Relationship Satisfaction Labels  \
# 322            Mid-Level                        Satisfied
# 439               Senior                Very Dissatisfied
# 1266  Associate / Junior                     Dissatisfied
# 671   Associate / Junior                     Dissatisfied
# 1249  Associate / Junior                        Satisfied
#
#       Avg Tenure Per Company           Candidate Stability  \
# 322                      1.4       Low Stability (< 2 yrs)
# 439                      4.0  Moderate Stability (2-5 yrs)
# 1266                     5.0  Moderate Stability (2-5 yrs)
# 671                      1.0       Low Stability (< 2 yrs)
# 1249                     2.0       Low Stability (< 2 yrs)
#
#       Training Intensity Work Life Balance Labels  Role Stagnation Index  \
# 322                  0.0                     Fair                    1.0
# 439                  2.0                     Good                    0.0
# 1266                 0.4                     Good                    0.6
# 671                  3.0                     Good                    0.0
# 1249                 1.5                     Good                    1.0
#
#       Promotion Gap Ratio  Manager Stability Indicator  \
# 322                   0.0                            3
# 439                   0.0                            1
# 1266                  0.0                            2
# 671                   1.0                            1
# 1249                  1.0                            2
#
#      Manager Stability Indicator Labels      Promotion Risk Cluster
# 322                              Stable     Role-Stagnant Mid-Level
# 439                    New Relationship      Early-Career Explorers
# 1266                         Developing  Fast-Track High Performers
# 671                    New Relationship      Early-Career Explorers
# 1249                         Developing      Early-Career Explorers

# %% [markdown]
# ---

# %% [markdown]
# ### **Histogram**

# %%
fig = px.histogram(df, x='Education Field', color='Education Field', text_auto=True)        # text position shows the count labels
fig.update_traces(textposition='outside')                                                   # shows the count labels outside of histplots
fig.show()

# %%
fig = px.histogram(df, x='Job Role', color='Job Role', text_auto=True, height=600)
fig.update_traces(textposition='outside')
fig.show()

# %%
fig = px.histogram(df, x='Education Field', color='Education Field', color_discrete_sequence=['red','blue','black','green','yellow','purple'], text_auto=True)
fig.update_traces(textposition='outside')
fig.show()

# %%
df['Education Field'].value_counts().reset_index()
# Out:
#     Education Field  count
# 0     Life Sciences    606
# 1           Medical    464
# 2         Marketing    159
# 3  Technical Degree    132
# 4             Other     82
# 5   Human Resources     27

# %%
temp = df['Education Field'].value_counts().reset_index()
px.histogram(temp, x='Education Field', y='count', color='Education Field', text_auto=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Using Inbuild Plotly
# ### **Barplot**

# %%
px.data.gapminder()                         # using Gapminder dataset
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
df = px.data.gapminder()

# %%
with pd.option_context('display.max_rows',None):
    display(df['country'].value_counts())
# Out:
# country
# Afghanistan                 12
# Pakistan                    12
# New Zealand                 12
# Nicaragua                   12
# Niger                       12
# Nigeria                     12
# Norway                      12
# Oman                        12
# Panama                      12
# Nepal                       12
# Paraguay                    12
# Peru                        12
# Philippines                 12
# Poland                      12
# Portugal                    12
# Puerto Rico                 12
# Netherlands                 12
# Namibia                     12
# Romania                     12
# Mali                        12
# Lesotho                     12
# Liberia                     12
# Libya                       12
# Madagascar                  12
# Malawi                      12
# Malaysia                    12
# Mauritania                  12
# Myanmar                     12
# Mauritius                   12
# Mexico                      12
# Mongolia                    12
# Montenegro                  12
# Morocco                     12
# Mozambique                  12
# Reunion                     12
# Rwanda                      12
# Albania                     12
# United Kingdom              12
# Thailand                    12
# Togo                        12
# Trinidad and Tobago         12
# Tunisia                     12
# Turkey                      12
# Uganda                      12
# United States               12
# Taiwan                      12
# Uruguay                     12
# Venezuela                   12
# Vietnam                     12
# West Bank and Gaza          12
# Yemen, Rep.                 12
# Zambia                      12
# Tanzania                    12
# Syria                       12
# Sao Tome and Principe       12
# Slovenia                    12
# Saudi Arabia                12
# Senegal                     12
# Serbia                      12
# Sierra Leone                12
# Singapore                   12
# Slovak Republic             12
# Somalia                     12
# Switzerland                 12
# South Africa                12
# Spain                       12
# Sri Lanka                   12
# Sudan                       12
# Swaziland                   12
# Sweden                      12
# Lebanon                     12
# Kuwait                      12
# Korea, Rep.                 12
# Comoros                     12
# Canada                      12
# Central African Republic    12
# Chad                        12
# Chile                       12
# China                       12
# Colombia                    12
# Congo, Dem. Rep.            12
# Cambodia                    12
# Congo, Rep.                 12
# Costa Rica                  12
# Cote d'Ivoire               12
# Croatia                     12
# Cuba                        12
# Czech Republic              12
# Cameroon                    12
# Burundi                     12
# Korea, Dem. Rep.            12
# Bangladesh                  12
# Algeria                     12
# Angola                      12
# Argentina                   12
# Australia                   12
# Austria                     12
# Bahrain                     12
# Belgium                     12
# Burkina Faso                12
# Benin                       12
# Bolivia                     12
# Bosnia and Herzegovina      12
# Botswana                    12
# Brazil                      12
# Bulgaria                    12
# Denmark                     12
# Djibouti                    12
# Dominican Republic          12
# Iraq                        12
# Hong Kong, China            12
# Hungary                     12
# Iceland                     12
# India                       12
# Indonesia                   12
# Iran                        12
# Ireland                     12
# Ecuador                     12
# Israel                      12
# Italy                       12
# Jamaica                     12
# Japan                       12
# Jordan                      12
# Kenya                       12
# Honduras                    12
# Haiti                       12
# Guinea-Bissau               12
# Guinea                      12
# Guatemala                   12
# Greece                      12
# Ghana                       12
# Germany                     12
# Gambia                      12
# Gabon                       12
# France                      12
# Finland                     12
# Ethiopia                    12
# Eritrea                     12
# Equatorial Guinea           12
# El Salvador                 12
# Egypt                       12
# Zimbabwe                    12
# Name: count, dtype: int64

# %%
canada = df[df['country'] == 'Canada']

# %%
canada
# Out:
#     country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 240  Canada  Americas  1952   68.750  14785584  11367.16112       CAN      124
# 241  Canada  Americas  1957   69.960  17010154  12489.95006       CAN      124
# 242  Canada  Americas  1962   71.300  18985849  13462.48555       CAN      124
# 243  Canada  Americas  1967   72.130  20819767  16076.58803       CAN      124
# 244  Canada  Americas  1972   72.880  22284500  18970.57086       CAN      124
# 245  Canada  Americas  1977   74.210  23796400  22090.88306       CAN      124
# 246  Canada  Americas  1982   75.760  25201900  22898.79214       CAN      124
# 247  Canada  Americas  1987   76.860  26549700  26626.51503       CAN      124
# 248  Canada  Americas  1992   77.950  28523502  26342.88426       CAN      124
# 249  Canada  Americas  1997   78.610  30305843  28954.92589       CAN      124
# 250  Canada  Americas  2002   79.770  31902268  33328.96507       CAN      124
# 251  Canada  Americas  2007   80.653  33390141  36319.23501       CAN      124

# %%
fig = px.bar(canada, x='year',y='pop', width=550, height=600, text='year', color='pop',
        hover_data=['lifeExp', 'gdpPercap','continent','country'],                    # the respected feature data will be displayed when featured over the data
        title='Population of Canada Over the Years',
        color_continuous_scale = ['green','yellow','red']                             # setting the color format from green to yellow to red
)

fig.update_layout(title_x=0.5)                                                        # puts the heading of the plot to the center

# %%
fig = px.bar(canada, x='year',y='lifeExp', width=550, height=600, text='year', color='pop',                 
        labels = {'lifeExp':'Life Expectancy',
                'year':'Year',
                'pop':'Population'
                  },                         # changes the names of the features
        title='Population of Canada Over the Years',
        color_continuous_scale = ['green','yellow','red']                          
)

fig.update_layout(title_x=0.5)

# %%
# using groupby -- only contains year and gdpPercap
data = df.groupby('year', as_index=False)['gdpPercap'].mean().round(2)


fig = px.bar(data, x='year', y='gdpPercap', text='gdpPercap',
            title='GDP Per Capital Over the Years',
            width=700,
            color='gdpPercap',
            color_continuous_scale=['green','yellow','red']
)
fig.update_layout(title_x=0.5)
fig.show()

# %% [markdown]
# ### Making new dataset

# %%
df = px.data.medals_long()                  # dataset on countries owning the medals

# %%
df
# Out:
#         nation   medal  count
# 0  South Korea    gold     24
# 1        China    gold     10
# 2       Canada    gold      9
# 3  South Korea  silver     13
# 4        China  silver     15
# 5       Canada  silver     12
# 6  South Korea  bronze     11
# 7        China  bronze      8
# 8       Canada  bronze     12

# %%
px.bar(df, x='nation',y='count',color='medal', width=600,
        color_discrete_map={            # setting different colors to different medal types
            'gold':'red',
            'silver':'green',
            'bronze':'blue'
        },
        text = 'medal'
       )

# %% [markdown]
# ---

# %% [markdown]
# ### **Lineplot**
